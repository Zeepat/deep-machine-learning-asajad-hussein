# %%
import keras
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import pandas as pd
import matplotlib.pyplot as plt
from keras import layers
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
y_test, y_train = y_test.ravel(), y_train.ravel()

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000,), (10000,))

# %%
df = pd.DataFrame(y_train)
df[0].unique()
# Out:
# array([6, 9, 4, 1, 2, 7, 8, 3, 5, 0], dtype=uint8)

# %%
labels = [
    'airplane', 
    'automobile', 
    'bird', 
    'cat', 
    'deer', 
    'dog', 
    'frog', 
    'horse', 
    'ship', 
    'truck'
    ]

labels_dict = {i: labels[i] for i in range(10)}

# %%
fig, axes = plt.subplots(2, 5, figsize=(10, 4))

for i, ax in enumerate(axes.flatten()):
    ax.imshow(X_train[i])
    ax.axis('off')
    ax.set_title(f"{y_train[i]}: {labels_dict[y_train[i]]}")

plt.tight_layout()

# %%
scaled_X_train = X_train.astype('float32') / 255
scaled_X_test = X_test.astype('float32') / 255

# %%
def CNN_model(learning_rate = 0.001, drop_rate=0.5, kernels=[32,64]):
    adam = keras.optimizers.Adam(learning_rate=learning_rate)
    model = keras.models.Sequential(name='CNN')

    for kern in kernels:
        conv_layer = layers.Conv2D(kern, 
                                   kernel_size = 3, 
                                   activation='relu', 
                                   kernel_initializer='he_normal', 
                                   input_shape=X_train.shape[1:]
                                   )
        model.add(conv_layer)
        model.add(layers.MaxPooling2D(pool_size=2, strides=2))
    model.add(layers.Flatten())
    model.add(layers.Dropout(drop_rate))
    model.add(layers.Dense(256, activation='relu', kernel_initializer='he_normal'))
    model.add(layers.Dense(10, activation='softmax'))

    model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
model = CNN_model(0.001, 0.5, [32, 64, 32])
model.summary()
# Out:
# /Users/asajad/Desktop/GithubForSchool/deep-machine-learning-asajad-hussein/.venv/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 32)       │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73,450 (286.91 KB)
#  Trainable params: 73,450 (286.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopper = EarlyStopping(monitor='val_loss', mode="min",patience=15)

model.fit(scaled_X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stopper])
# Out:
# Epoch 1/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.2122 - loss: 2.0872 - val_accuracy: 0.4170 - val_loss: 1.5894
# Epoch 2/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.4119 - loss: 1.5687 - val_accuracy: 0.5269 - val_loss: 1.3154
# Epoch 3/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.4848 - loss: 1.4075 - val_accuracy: 0.5473 - val_loss: 1.2520
# Epoch 4/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5168 - loss: 1.3156 - val_accuracy: 0.5866 - val_loss: 1.1743
# Epoch 5/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.5507 - loss: 1.2389 - val_accuracy: 0.6003 - val_loss: 1.1399
# Epoch 6/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5767 - loss: 1.1738 - val_accuracy: 0.6206 - val_loss: 1.0769
# Epoch 7/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.5920 - loss: 1.1392 - val_accuracy: 0.6427 - val_loss: 1.0352
# Epoch 8/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6066 - loss: 1.0978 - val_accuracy: 0.6468 - val_loss: 1.0035
# Epoch 9/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6171 - loss: 1.0582 - val_accuracy: 0.6565 - val_loss: 1.0076
# Epoch 10/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6241 - loss: 1.0402 - val_accuracy: 0.6643 - val_loss: 0.9676
# Epoch 11/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6357 - loss: 1.0197 - val_accuracy: 0.6645 - val_loss: 0.9548
# Epoch 12/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6373 - loss: 1.0052 - val_accuracy: 0.6749 - val_loss: 0.9515
# Epoch 13/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6435 - loss: 0.9937 - val_accuracy: 0.6806 - val_loss: 0.9448
# Epoch 14/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6516 - loss: 0.9713 - val_accuracy: 0.6738 - val_loss: 0.9357
# Epoch 15/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6603 - loss: 0.9531 - val_accuracy: 0.6686 - val_loss: 0.9402
# Epoch 16/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6602 - loss: 0.9554 - val_accuracy: 0.6663 - val_loss: 0.9563
# Epoch 17/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6636 - loss: 0.9366 - val_accuracy: 0.6855 - val_loss: 0.9175
# Epoch 18/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6721 - loss: 0.9137 - val_accuracy: 0.6903 - val_loss: 0.9018
# Epoch 19/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.6726 - loss: 0.9099 - val_accuracy: 0.6863 - val_loss: 0.9103
# Epoch 20/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6820 - loss: 0.8907 - val_accuracy: 0.6904 - val_loss: 0.8995
# Epoch 21/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6816 - loss: 0.8847 - val_accuracy: 0.6935 - val_loss: 0.8963
# Epoch 22/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6949 - loss: 0.8608 - val_accuracy: 0.6839 - val_loss: 0.9132
# Epoch 23/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - accuracy: 0.6931 - loss: 0.8612 - val_accuracy: 0.7055 - val_loss: 0.8639
# Epoch 24/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.6905 - loss: 0.8567 - val_accuracy: 0.6897 - val_loss: 0.8988
# Epoch 25/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7065 - loss: 0.8296 - val_accuracy: 0.7033 - val_loss: 0.8703
# Epoch 26/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.7027 - loss: 0.8293 - val_accuracy: 0.7090 - val_loss: 0.8492
# Epoch 27/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.7022 - loss: 0.8323 - val_accuracy: 0.6806 - val_loss: 0.9144
# Epoch 28/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7057 - loss: 0.8285 - val_accuracy: 0.7003 - val_loss: 0.8672
# Epoch 29/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7122 - loss: 0.8100 - val_accuracy: 0.6933 - val_loss: 0.8774
# Epoch 30/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.7155 - loss: 0.8031 - val_accuracy: 0.6993 - val_loss: 0.8735
# Epoch 31/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - accuracy: 0.7119 - loss: 0.8030 - val_accuracy: 0.7025 - val_loss: 0.8491
# Epoch 32/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7219 - loss: 0.7881 - val_accuracy: 0.6963 - val_loss: 0.8715
# Epoch 33/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.7209 - loss: 0.7949 - val_accuracy: 0.6989 - val_loss: 0.8717
# Epoch 34/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 180s 144ms/step - accuracy: 0.7265 - loss: 0.7730 - val_accuracy: 0.6975 - val_loss: 0.8652
# Epoch 35/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7215 - loss: 0.7808 - val_accuracy: 0.6986 - val_loss: 0.8665
# Epoch 36/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.7197 - loss: 0.7772 - val_accuracy: 0.7017 - val_loss: 0.8504
# Epoch 37/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.7226 - loss: 0.7763 - val_accuracy: 0.6918 - val_loss: 0.8750
# Epoch 38/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7262 - loss: 0.7688 - val_accuracy: 0.7128 - val_loss: 0.8296
# Epoch 39/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7325 - loss: 0.7621 - val_accuracy: 0.7111 - val_loss: 0.8434
# Epoch 40/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7321 - loss: 0.7518 - val_accuracy: 0.7082 - val_loss: 0.8370
# Epoch 41/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7311 - loss: 0.7581 - val_accuracy: 0.7036 - val_loss: 0.8651
# Epoch 42/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7350 - loss: 0.7572 - val_accuracy: 0.7026 - val_loss: 0.8507
# Epoch 43/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7305 - loss: 0.7529 - val_accuracy: 0.7028 - val_loss: 0.8537
# Epoch 44/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7343 - loss: 0.7381 - val_accuracy: 0.7127 - val_loss: 0.8309
# Epoch 45/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7386 - loss: 0.7302 - val_accuracy: 0.7045 - val_loss: 0.8396
# Epoch 46/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7357 - loss: 0.7425 - val_accuracy: 0.7119 - val_loss: 0.8289
# Epoch 47/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7392 - loss: 0.7345 - val_accuracy: 0.7052 - val_loss: 0.8386
# Epoch 48/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7390 - loss: 0.7261 - val_accuracy: 0.7026 - val_loss: 0.8498
# Epoch 49/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7386 - loss: 0.7274 - val_accuracy: 0.7108 - val_loss: 0.8338
# Epoch 50/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7467 - loss: 0.7159 - val_accuracy: 0.7117 - val_loss: 0.8253
# Epoch 51/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7429 - loss: 0.7229 - val_accuracy: 0.7092 - val_loss: 0.8470
# Epoch 52/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7500 - loss: 0.7058 - val_accuracy: 0.7193 - val_loss: 0.8270
# Epoch 53/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.7462 - loss: 0.7147 - val_accuracy: 0.7096 - val_loss: 0.8347
# Epoch 54/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7429 - loss: 0.7153 - val_accuracy: 0.7017 - val_loss: 0.8467
# Epoch 55/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.7459 - loss: 0.7136 - val_accuracy: 0.7049 - val_loss: 0.8469
# Epoch 56/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.7537 - loss: 0.7056 - val_accuracy: 0.7111 - val_loss: 0.8352
# Epoch 57/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7531 - loss: 0.6938 - val_accuracy: 0.7120 - val_loss: 0.8266
# Epoch 58/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7518 - loss: 0.6962 - val_accuracy: 0.7129 - val_loss: 0.8282
# Epoch 59/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.7505 - loss: 0.7042 - val_accuracy: 0.6984 - val_loss: 0.8542
# Epoch 60/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7538 - loss: 0.6978 - val_accuracy: 0.6934 - val_loss: 0.8649
# Epoch 61/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7572 - loss: 0.6865 - val_accuracy: 0.7012 - val_loss: 0.8613
# Epoch 62/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7543 - loss: 0.6913 - val_accuracy: 0.7189 - val_loss: 0.8133
# Epoch 63/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7553 - loss: 0.6864 - val_accuracy: 0.7165 - val_loss: 0.8259
# Epoch 64/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7587 - loss: 0.6760 - val_accuracy: 0.7108 - val_loss: 0.8283
# Epoch 65/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7530 - loss: 0.6947 - val_accuracy: 0.7062 - val_loss: 0.8314
# Epoch 66/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7574 - loss: 0.6826 - val_accuracy: 0.7123 - val_loss: 0.8362
# Epoch 67/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7605 - loss: 0.6784 - val_accuracy: 0.7116 - val_loss: 0.8146
# Epoch 68/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.7598 - loss: 0.6791 - val_accuracy: 0.7161 - val_loss: 0.8273
# Epoch 69/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.7574 - loss: 0.6812 - val_accuracy: 0.7145 - val_loss: 0.8311
# Epoch 70/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7650 - loss: 0.6604 - val_accuracy: 0.6993 - val_loss: 0.8491
# Epoch 71/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7639 - loss: 0.6654 - val_accuracy: 0.7208 - val_loss: 0.8153
# Epoch 72/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.7610 - loss: 0.6699 - val_accuracy: 0.7129 - val_loss: 0.8375
# Epoch 73/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7606 - loss: 0.6777 - val_accuracy: 0.7105 - val_loss: 0.8223
# Epoch 74/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7634 - loss: 0.6598 - val_accuracy: 0.7104 - val_loss: 0.8337
# Epoch 75/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.7635 - loss: 0.6643 - val_accuracy: 0.7136 - val_loss: 0.8305
# Epoch 76/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.7638 - loss: 0.6696 - val_accuracy: 0.7130 - val_loss: 0.8332
# Epoch 77/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7683 - loss: 0.6556 - val_accuracy: 0.7085 - val_loss: 0.8433

# %%
metrics = pd.DataFrame(model.history.history)
metrics.head()
# Out:
#    accuracy      loss  val_accuracy  val_loss
# 0  0.287225  1.884567        0.4170  1.589364
# 1  0.434375  1.523307        0.5269  1.315370
# 2  0.492850  1.385755        0.5473  1.252045
# 3  0.527350  1.297327        0.5866  1.174309
# 4  0.556200  1.226557        0.6003  1.139884

# %%
def plot_metrics(metrics):
    _, axes = plt.subplots(1, 2, figsize=(12, 4))
    metrics[['loss', 'val_loss']].plot(ax=axes[0])
    metrics[['accuracy', 'val_accuracy']].plot(ax=axes[1])

plot_metrics(metrics)

# %%
early_stopper = EarlyStopping(monitor='val_loss', mode="min",patience=5, restore_best_weights=True)

def evaluate_model(**kwargs):
    model = CNN_model(**kwargs)
    model.fit(
        scaled_X_train, 
        y_train, 
        epochs=20, 
        validation_split=1/6, 
        callbacks=[early_stopper]
        )
    metrics = pd.DataFrame(model.history.history)
    val_acc = metrics['val_accuracy'].iloc[-1]
    return val_acc

# %%
dropout_accuracies = {}
for drop_rate in np.arange(0.1, 0.6, 0.1):
    dropout_accuracies[drop_rate] = evaluate_model(drop_rate=drop_rate)
# Out:
# /Users/asajad/Desktop/GithubForSchool/deep-machine-learning-asajad-hussein/.venv/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 5
#       3 dropout_accuracies = {}
#       4 for drop_rate in np.arange(0.1, 0.6, 0.1):
# ----> 5     dropout_accuracies[drop_rate] = evaluate_model(drop_rate=drop_rate)
#
# Cell In[37], line 5, in evaluate_model(**kwargs)
#       3 def evaluate_model(**kwargs):
#       4     model = CNN_model(**kwargs)
# ----> 5     model.fit(
#       6         scaled_X_train,
#       7         y_train,
#       8         epochs=20,
#       9         validation_split=1/6,
#      10         callbacks=[early_stopper],
#      11         workers=8
#      12         )
#      13     metrics = pd.DataFrame(model.history.history)
#      14     val_acc = metrics['val_accuracy'].iloc[-1]
#
# File ~/Desktop/GithubForSchool/deep-machine-learning-asajad-hussein/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/Desktop/GithubForSchool/deep-machine-learning-asajad-hussein/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# TypeError: TensorFlowTrainer.fit() got an unexpected keyword argument 'workers'
